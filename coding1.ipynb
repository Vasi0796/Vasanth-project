# %% [markdown]
# # Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Loading

# %%
# Importing Loan data
data = pd.read_csv('Loan.csv')

# %% [markdown]
# # Data Exploration

# %%
# First Few Rows
data.head(5)
# Out:
#   ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0      2018-01-01   45         39948          617         Employed
# 1      2018-01-02   38         39709          628         Employed
# 2      2018-01-03   47         40724          570         Employed
# 3      2018-01-04   58         69084          545         Employed
# 4      2018-01-05   37        103264          594         Employed
#
#   EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  ...  \
# 0         Master          22       13152            48       Married  ...
# 1      Associate          15       26045            48        Single  ...
# 2       Bachelor          26       17627            36       Married  ...
# 3    High School          34       37898            96        Single  ...
# 4      Associate          17        9184            36       Married  ...
#
#    MonthlyIncome UtilityBillsPaymentHistory  JobTenure  NetWorth  \
# ...

# %%
# Last Few Rows 
data.tail(5)
# Out:
#       ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 19995      2072-09-29   44         30180          587         Employed
# 19996      2072-09-30   56         49246          567         Employed
# 19997      2072-10-01   44         48958          645         Employed
# 19998      2072-10-02   60         41025          560         Employed
# 19999      2072-10-03   20         53227          574         Employed
#
#       EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  ...  \
# 19995    High School          19       24521            36       Married  ...
# 19996      Associate          33       25818            36       Married  ...
# 19997       Bachelor          20       37033            72       Married  ...
# 19998    High School          36       14760            72       Married  ...
# 19999      Associate           0       32055            48       Married  ...
#
# ...

# %%
# shape of the Dataset
data.shape
# Out:
# (20000, 36)

# %%
# Columns present in the dataset
data.columns
# Out:
# Index(['ApplicationDate', 'Age', 'AnnualIncome', 'CreditScore',
#        'EmploymentStatus', 'EducationLevel', 'Experience', 'LoanAmount',
#        'LoanDuration', 'MaritalStatus', 'NumberOfDependents',
#        'HomeOwnershipStatus', 'MonthlyDebtPayments',
#        'CreditCardUtilizationRate', 'NumberOfOpenCreditLines',
#        'NumberOfCreditInquiries', 'DebtToIncomeRatio', 'BankruptcyHistory',
#        'LoanPurpose', 'PreviousLoanDefaults', 'PaymentHistory',
#        'LengthOfCreditHistory', 'SavingsAccountBalance',
#        'CheckingAccountBalance', 'TotalAssets', 'TotalLiabilities',
#        'MonthlyIncome', 'UtilityBillsPaymentHistory', 'JobTenure', 'NetWorth',
#        'BaseInterestRate', 'InterestRate', 'MonthlyLoanPayment',
#        'TotalDebtToIncomeRatio', 'LoanApproved', 'RiskScore'],
#       dtype='object')

# %%
# Data types of each feature
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ApplicationDate             20000 non-null  object
#  1   Age                         20000 non-null  int64
#  2   AnnualIncome                20000 non-null  int64
#  3   CreditScore                 20000 non-null  int64
#  4   EmploymentStatus            20000 non-null  object
#  5   EducationLevel              20000 non-null  object
#  6   Experience                  20000 non-null  int64
#  7   LoanAmount                  20000 non-null  int64
#  8   LoanDuration                20000 non-null  int64
#  9   MaritalStatus               20000 non-null  object
#  10  NumberOfDependents          20000 non-null  int64
#  11  HomeOwnershipStatus         20000 non-null  object
#  12  MonthlyDebtPayments         20000 non-null  int64
# ...

# %% [markdown]
# # Data Cleaning and Preparation

# %%
# Checking Null values
data.isnull().sum()
# Out:
# ApplicationDate               0
# Age                           0
# AnnualIncome                  0
# CreditScore                   0
# EmploymentStatus              0
# EducationLevel                0
# Experience                    0
# LoanAmount                    0
# LoanDuration                  0
# MaritalStatus                 0
# NumberOfDependents            0
# HomeOwnershipStatus           0
# MonthlyDebtPayments           0
# CreditCardUtilizationRate     0
# NumberOfOpenCreditLines       0
# NumberOfCreditInquiries       0
# DebtToIncomeRatio             0
# BankruptcyHistory             0
# LoanPurpose                   0
# PreviousLoanDefaults          0
# PaymentHistory                0
# LengthOfCreditHistory         0
# SavingsAccountBalance         0
# CheckingAccountBalance        0
# TotalAssets                   0
# TotalLiabilities              0
# MonthlyIncome                 0
# UtilityBillsPaymentHistory    0
# JobTenure                     0
# ...

# %%
# Checking Duplicate Values
data.duplicated().sum()
# Out:
# 0

# %%
# Data preparation
data['ApplicationDate'] = pd.to_datetime(data['ApplicationDate'])
data.set_index('ApplicationDate', inplace=True)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Statistical Analysis
data.describe()
# Out:
#                 Age   AnnualIncome   CreditScore    Experience     LoanAmount  \
# count  20000.000000   20000.000000  20000.000000  20000.000000   20000.000000
# mean      39.752600   59161.473550    571.612400     17.522750   24882.867800
# std       11.622713   40350.845168     50.997358     11.316836   13427.421217
# min       18.000000   15000.000000    343.000000      0.000000    3674.000000
# 25%       32.000000   31679.000000    540.000000      9.000000   15575.000000
# 50%       40.000000   48566.000000    578.000000     17.000000   21914.500000
# 75%       48.000000   74391.000000    609.000000     25.000000   30835.000000
# max       80.000000  485341.000000    712.000000     61.000000  184732.000000
#
#        LoanDuration  NumberOfDependents  MonthlyDebtPayments  \
# count  20000.000000        20000.000000         20000.000000
# mean      54.057000            1.517300           454.292700
# std       24.664857            1.386325           240.507609
# ...

# %%
# Data visualisations

# %%
# Set a consistent theme for the visualizations
sns.set_theme(style="whitegrid")

# Distribution of Risk Scores
plt.figure(figsize=(10, 6))
sns.histplot(data['RiskScore'], kde=True, bins=30, color='blue')
plt.title("Distribution of Risk Scores", fontsize=16)
plt.xlabel("Risk Score", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.show()

# %%
# Loan Purpose and Risk Score
plt.figure(figsize=(14, 8))
sns.boxplot(data=data, x='LoanPurpose', y='RiskScore', palette="muted")
plt.title("Risk Score Distribution by Loan Purpose", fontsize=16)
plt.xlabel("Loan Purpose", fontsize=14)
plt.ylabel("Risk Score", fontsize=14)
plt.xticks(rotation=45)
plt.show()

# %%
# Loan Duration and Risk Score
average_risk_score_by_duration = data.groupby('LoanDuration').agg(
    RiskScore=('RiskScore', 'mean'),
    Count=('RiskScore', 'size')
).reset_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=average_risk_score_by_duration,
    x='LoanDuration',
    y='RiskScore',
    palette="Spectral"
)

# Add annotations for the counts on top of each bar
for i, row in average_risk_score_by_duration.iterrows():
    plt.text(i, row['RiskScore'] + 0.2, f"{row['Count']}", ha='center', fontsize=12, color='black', weight='bold')

# Add titles and labels
plt.title("Average Risk Score by Loan Duration", fontsize=16, weight='bold')
plt.xlabel("Loan Duration (Months)", fontsize=14)
plt.ylabel("Average Risk Score", fontsize=14)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Employment Status vs Risk Score
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='EmploymentStatus', y='RiskScore', palette="Set3")
plt.title("Employment Status vs Risk Score", fontsize=16)
plt.xlabel("Employment Status", fontsize=14)
plt.ylabel("Risk Score", fontsize=14)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
data['EmploymentStatus'].unique()
# Out:
# array(['Employed', 'Self-Employed', 'Unemployed'], dtype=object)

# %%
# Education Level vs Risk Score
education_count = data['EducationLevel'].value_counts().reset_index(name='Count')
education_count.columns = ['EducationLevel', 'Count']

# Create a horizontal bar plot
plt.figure(figsize=(10, 6))
ax = sns.barplot(data=education_count, x='Count', y='EducationLevel', palette="coolwarm")

# Add counts on top of the bars
for p in ax.patches:
    ax.text(p.get_width() + 0.1, p.get_y() + p.get_height() / 2, 
            f'{int(p.get_width())}', 
            ha='center', va='center', fontsize=12, weight='bold')

# Add titles and labels
plt.title("Distribution of Education Level with Counts", fontsize=16)
plt.xlabel("Count", fontsize=14)
plt.ylabel("Education Level", fontsize=14)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# 3. Marital Status vs Loan Approval
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=data, x='MaritalStatus', hue='LoanApproved', palette="pastel")

# Add counts on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2, p.get_height() + 1, 
            f'{int(p.get_height())}', 
            ha='center', va='bottom', fontsize=12, weight='bold')

# Add titles and labels
plt.title("Marital Status vs Loan Approval", fontsize=16)
plt.xlabel("Marital Status", fontsize=14)
plt.ylabel("Count", fontsize=14)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# 4. Home Ownership Status vs Loan Approval
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=data, x='HomeOwnershipStatus', hue='LoanApproved', palette="muted")

# Add counts on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2, p.get_height() + 1, 
            f'{int(p.get_height())}', 
            ha='center', va='bottom', fontsize=12, weight='bold')

# Add titles and labels
plt.title("Home Ownership Status vs Loan Approval", fontsize=16)
plt.xlabel("Home Ownership Status", fontsize=14)
plt.ylabel("Count", fontsize=14)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# 5. Employment Status vs Loan Approval (count plot)
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=data, x='EmploymentStatus', hue='LoanApproved', palette="Set2")

# Add counts on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2, p.get_height() + 1, 
            f'{int(p.get_height())}', 
            ha='center', va='bottom', fontsize=12, weight='bold')

# Add titles and labels
plt.title("Employment Status vs Loan Approval", fontsize=16)
plt.xlabel("Employment Status", fontsize=14)
plt.ylabel("Count", fontsize=14)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# Create a label encoder object
label_encoder = LabelEncoder()

# List of categorical columns to encode
categorical_columns = ['EmploymentStatus', 'EducationLevel', 'MaritalStatus', 'HomeOwnershipStatus', 'LoanPurpose']

# Apply label encoder to each categorical column
for col in categorical_columns:
    data[col] = label_encoder.fit_transform(data[col])

# %% [markdown]
# # Feature Selection using Correlation with LoanApproved:

# %%
# Correlation with LoanApproved
correlation_with_loan_approved = data.corr()['LoanApproved'].sort_values(ascending=False)

# Display the correlations with LoanApproved
print("Correlation with Loan Approved:")
print(correlation_with_loan_approved)
# Out:
# Correlation with Loan Approved:
# LoanApproved                  1.000000
# MonthlyIncome                 0.604101
# AnnualIncome                  0.597900
# NetWorth                      0.187892
# TotalAssets                   0.184011
# CreditScore                   0.142000
# Age                           0.141029
# Experience                    0.140755
# LengthOfCreditHistory         0.105949
# PaymentHistory                0.030804
# EducationLevel                0.019650
# JobTenure                     0.004997
# UtilityBillsPaymentHistory    0.003303
# NumberOfDependents            0.001717
# SavingsAccountBalance         0.000961
# CheckingAccountBalance        0.000660
# DebtToIncomeRatio             0.000034
# NumberOfOpenCreditLines      -0.004769
# NumberOfCreditInquiries      -0.005885
# MaritalStatus                -0.006828
# LoanPurpose                  -0.007062
# CreditCardUtilizationRate    -0.010466
# HomeOwnershipStatus          -0.018135
# ...

# %% [markdown]
# # Data Splitting for Classification Models

# %%
X = data.drop(columns=['LoanApproved', 'RiskScore'])
y = data['LoanApproved']

# %%
# Using SMOTE for making the class balance
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Splitting data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Applying SMOTE to the training set
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Checking class distribution after applying SMOTE
print("Class distribution before SMOTE:")
print(y_train.value_counts())

print("\nClass distribution after SMOTE:")
print(y_train_resampled.value_counts())
# Out:
# Class distribution before SMOTE:
# LoanApproved
# 0    10654
# 1     3346
# Name: count, dtype: int64
#
# Class distribution after SMOTE:
# LoanApproved
# 0    10654
# 1    10654
# Name: count, dtype: int64

# %%
X_train_resampled.head(10)
# Out:
#    Age  AnnualIncome  CreditScore  EmploymentStatus  EducationLevel  \
# 0   19         50859          538                 0               1
# 1   36         70618          605                 0               3
# 2   40         30117          616                 0               3
# 3   42         43785          556                 0               2
# 4   31         31830          596                 0               3
# 5   40         21133          616                 0               3
# 6   30         49162          545                 0               0
# 7   52         78392          645                 0               4
# 8   34         45850          603                 1               0
# 9   41         94576          588                 0               1
#
#    Experience  LoanAmount  LoanDuration  MaritalStatus  NumberOfDependents  \
# 0           0       29668            72              1                   5
# ...

# %%
# Checking the class balance
# Visualizing the class distribution after SMOTE
plt.figure(figsize=(8, 5))
sns.barplot(x=y_train_resampled.value_counts().index, 
            y=y_train_resampled.value_counts().values, 
            palette="viridis")
plt.title("Class Distribution After SMOTE", fontsize=16)
plt.xlabel("Class", fontsize=14)
plt.ylabel("Count", fontsize=14)
for i, count in enumerate(y_train_resampled.value_counts().values):
    plt.text(i, count + 0.02 * max(y_train_resampled.value_counts().values), 
             str(count), ha='center', fontsize=12)
plt.show()

# %%
# Perform the data split (70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Verify the shapes of the resulting splits
print(f"Training Features Shape: {X_train.shape}")
print(f"Testing Features Shape: {X_test.shape}")
print(f"Training Target Shape: {y_train.shape}")
print(f"Testing Target Shape: {y_test.shape}")
# Out:
# Training Features Shape: (14000, 33)
# Testing Features Shape: (6000, 33)
# Training Target Shape: (14000,)
# Testing Target Shape: (6000,)

# %% [markdown]
# # Classification Models Evaluation

# %% [markdown]
# ## 1. Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize the DecisionTreeClassifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# %%
# Train the model on the training data
dt_classifier.fit(X_train_resampled, y_train_resampled)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Predict the target variable on the test data
y_pred_dt = dt_classifier.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred_dt)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 96.48%

# %%
# Generate the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_dt))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      4522
#            1       0.93      0.93      0.93      1478
#
#     accuracy                           0.96      6000
#    macro avg       0.95      0.95      0.95      6000
# weighted avg       0.96      0.96      0.96      6000

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_dt)

# Plot the Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='rocket', xticklabels=['Not Approved', 'Approved'], yticklabels=['Not Approved', 'Approved'])
plt.title("Confusion Matrix (Decision Tree Classifier)", fontsize=16)
plt.xlabel("Predicted Labels", fontsize=14)
plt.ylabel("True Labels", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# Initialize the AdaBoostClassifier
ab_classifier = AdaBoostClassifier(random_state=42)

# %%
# Train the model on the training data
ab_classifier.fit(X_train_resampled, y_train_resampled)
# Out:
# AdaBoostClassifier(random_state=42)

# %%
# Predict the target variable on the test data
y_pred_ab = ab_classifier.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy_ab = accuracy_score(y_test, y_pred_ab)
print(f"Accuracy: {accuracy_ab * 100:.2f}%")
# Out:
# Accuracy: 94.02%

# %%
# Generate the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_ab))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      4522
#            1       0.85      0.92      0.88      1478
#
#     accuracy                           0.94      6000
#    macro avg       0.91      0.94      0.92      6000
# weighted avg       0.94      0.94      0.94      6000

# %%
# Confusion Matrix
conf_matrix_ada = confusion_matrix(y_test, y_pred_ab)

# Plot the Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_ada, annot=True, fmt='d', cmap='rocket', xticklabels=['Not Approved', 'Approved'], yticklabels=['Not Approved', 'Approved'])
plt.title("Confusion Matrix (AdaBoost Classifier)", fontsize=16)
plt.xlabel("Predicted Labels", fontsize=14)
plt.ylabel("True Labels", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Stacking Classifier

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Define base models (base learners)
base_learners = [
    ('decision_tree', DecisionTreeClassifier(random_state=42)),
    ('extra_trees', ExtraTreesClassifier(random_state=42)),
    ('random_forest', RandomForestClassifier(random_state=42))
]

# Define meta model (final estimator)
meta_model = LogisticRegression(random_state=42)

# Initialize the Stacking Classifier with the base learners and meta model
stacking_classifier = StackingClassifier(estimators=base_learners, final_estimator=meta_model)

# %%
# Train the Stacking Classifier on the training data
stacking_classifier.fit(X_train_resampled, y_train_resampled)
# Out:
# StackingClassifier(estimators=[('decision_tree',
#                                 DecisionTreeClassifier(random_state=42)),
#                                ('extra_trees',
#                                 ExtraTreesClassifier(random_state=42)),
#                                ('random_forest',
#                                 RandomForestClassifier(random_state=42))],
#                    final_estimator=LogisticRegression(random_state=42))

# %%
# Predict the target variable on the test data
y_pred_stack = stacking_classifier.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy_stack = accuracy_score(y_test, y_pred_stack)
print(f"Accuracy: {accuracy_stack * 100:.2f}%")
# Out:
# Accuracy: 97.77%

# %%
# Generate the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_stack))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      4522
#            1       0.96      0.95      0.95      1478
#
#     accuracy                           0.98      6000
#    macro avg       0.97      0.97      0.97      6000
# weighted avg       0.98      0.98      0.98      6000

# %%
# Confusion Matrix
conf_matrix_stack = confusion_matrix(y_test, y_pred_stack)

# Plot the Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_stack, annot=True, fmt='d', cmap='rocket', xticklabels=['Not Approved', 'Approved'], yticklabels=['Not Approved', 'Approved'])
plt.title("Confusion Matrix (Stacking Classifier)", fontsize=16)
plt.xlabel("Predicted Labels", fontsize=14)
plt.ylabel("True Labels", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Comparison for loan approval prediction

# %%
# Accuracy results from each model
models = ['Decision Tree', 'AdaBoost Classifier', 'Stacking Classifier']
accuracies = [accuracy * 100, accuracy_ab * 100, accuracy_stack * 100]

# Create a DataFrame for visualization
model_comparison = {
    'Model': models,
    'Accuracy': accuracies
}

# Plotting the bar chart for model comparison
plt.figure(figsize=(8, 6))
bar_plot = sns.barplot(x=model_comparison['Model'], y=model_comparison['Accuracy'], palette='viridis')

# Add the accuracy values on top of the bars
for i, v in enumerate(accuracies):
    bar_plot.text(i, v + 1, f"{v:.2f}%", ha='center', fontsize=12, color='black')

plt.title("Model Comparison: Accuracy (%)", fontsize=16)
plt.xlabel("Models", fontsize=14)
plt.ylabel("Accuracy (%)", fontsize=14)
plt.tight_layout()
plt.show()

# Conclusion
best_model = models[accuracies.index(max(accuracies))]  

# Display the conclusion
print(f"\nThe best fitted model for loan approval forecasting is the **{best_model}** with an accuracy of {max(accuracies):.2f}%.")
# Out:
# The best fitted model for loan approval forecasting is the **Stacking Classifier** with an accuracy of 97.77%.

# %% [markdown]
# ## Deploying the best-fitted Classification model

# %%
import pickle
pickle.dump(stacking_classifier, open("stacking_classifier.pkl", 'wb'))

# %%
model = pickle.load(open("stacking_classifier.pkl", 'rb'))

# %%
import tkinter as tk
from tkinter import messagebox

def predict():
    try:
       
        monthly_income = float(monthly_income_entry.get())
        annual_income = float(annual_income_entry.get())
        net_worth = float(net_worth_entry.get())
        total_assets = float(total_assets_entry.get())
        credit_score = float(credit_score_entry.get())
        age = int(age_entry.get())
        experience = int(experience_entry.get())
        length_of_credit_history = int(length_of_credit_history_entry.get())

        
        input_features = np.array([[
            monthly_income, annual_income, net_worth, total_assets,
            credit_score, age, experience, length_of_credit_history
        ]])

        
        prediction = model.predict(input_features)[0]
        
        
        result = "Loan Approved" if prediction == 1 else "Loan Not Approved"
        messagebox.showinfo("Prediction Result", result)
    except ValueError:
        messagebox.showerror("Invalid Input", "Please enter valid numerical values.")

# Creating the main application window
app = tk.Tk()
app.title("Loan Approval Predictor")
app.geometry("400x500")


labels = [
    "Monthly Income", "Annual Income", "Net Worth", "Total Assets",
    "Credit Score", "Age", "Experience", "Length of Credit History"
]

entries = []

for i, label_text in enumerate(labels):
    label = tk.Label(app, text=label_text, font=("Arial", 12))
    label.pack(pady=5)

    entry = tk.Entry(app, font=("Arial", 12))
    entry.pack(pady=5)
    entries.append(entry)

(monthly_income_entry, annual_income_entry, net_worth_entry, total_assets_entry,
 credit_score_entry, age_entry, experience_entry, length_of_credit_history_entry) = entries


predict_button = tk.Button(app, text="Predict", command=predict, font=("Arial", 14), bg="blue", fg="white")
predict_button.pack(pady=20)


app.mainloop()

# %% [markdown]
# # Feature Selection using Correlation with RiskScore:

# %%
# Correlation with RiskScore
correlation_with_risk_score = data.corr()['RiskScore'].sort_values(ascending=False)

# Display the correlations with RiskScore
print("Correlation with Risk Score:")
print(correlation_with_risk_score)
# Out:
# Correlation with Risk Score:
# RiskScore                     1.000000
# BankruptcyHistory             0.377578
# TotalDebtToIncomeRatio        0.342643
# DebtToIncomeRatio             0.326500
# InterestRate                  0.268203
# PreviousLoanDefaults          0.258659
# BaseInterestRate              0.256233
# LoanAmount                    0.137981
# EmploymentStatus              0.132964
# MonthlyLoanPayment            0.115501
# CreditCardUtilizationRate     0.108758
# TotalLiabilities              0.055617
# LoanDuration                  0.054550
# MonthlyDebtPayments           0.036938
# MaritalStatus                 0.016824
# NumberOfOpenCreditLines       0.007762
# LoanPurpose                   0.005521
# HomeOwnershipStatus           0.004454
# NumberOfCreditInquiries       0.003103
# SavingsAccountBalance         0.002190
# NumberOfDependents            0.001686
# CheckingAccountBalance       -0.004044
# JobTenure                    -0.004393
# ...

# %% [markdown]
# # Data Splitting for Regression Models

# %%
X_reg = data.drop(columns=['LoanApproved', 'RiskScore'])
y_reg = data['RiskScore']

# %%
# Split the data into training and testing sets (80% training, 20% testing)
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(X_reg, y_reg, test_size=0.2, random_state=42)

# Display the shape of the splits to confirm
print(f"Training data shape (X_train, y_train): {X_train_reg.shape}, {y_train_reg.shape}")
print(f"Testing data shape (X_test, y_test): {X_test_reg.shape}, {y_test_reg.shape}")
# Out:
# Training data shape (X_train, y_train): (16000, 33), (16000,)
# Testing data shape (X_test, y_test): (4000, 33), (4000,)

# %%
X_train_reg.head(10)
# Out:
#                  Age  AnnualIncome  CreditScore  EmploymentStatus  \
# ApplicationDate
# 2034-02-20        45         15000          620                 0
# 2028-03-17        25         49855          486                 0
# 2042-07-12        51         38932          576                 0
# 2039-01-02        18         58116          516                 2
# 2034-06-05        25         62939          562                 0
# 2033-09-30        25         64187          567                 2
# 2022-08-16        43         29872          607                 0
# 2036-09-19        51         70068          593                 0
# 2035-11-24        28        138416          526                 0
# 2031-04-05        48         49945          601                 0
#
#                  EducationLevel  Experience  LoanAmount  LoanDuration  \
# ApplicationDate
# 2034-02-20                    0          21       17419            36
# ...

# %% [markdown]
# ## 1. Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Initialize the Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
# Fit the model
rf_regressor.fit(X_train_reg, y_train_reg)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predict on the test data
y_pred_rf = rf_regressor.predict(X_test_reg)

# %%
# Calculate R-squared, MSE, RMSE, and MAE
r2_rf = r2_score(y_test_reg, y_pred_rf)
mse_rf = mean_squared_error(y_test_reg, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
mae_rf = mean_absolute_error(y_test_reg, y_pred_rf)

# Print the evaluation metrics
print(f"R-squared: {r2_rf:.4f}")
print(f"Mean Squared Error (MSE): {mse_rf:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_rf:.4f}")
print(f"Mean Absolute Error (MAE): {mae_rf:.4f}")
# Out:
# R-squared: 0.8785
# Mean Squared Error (MSE): 7.5431
# Root Mean Squared Error (RMSE): 2.7465
# Mean Absolute Error (MAE): 1.7082

# %%
# Plot Actual vs Predicted values
plt.figure(figsize=(10,6))
plt.scatter(y_test_reg, y_pred_rf, color='blue', alpha=0.6)
plt.plot([min(y_test_reg), max(y_test_reg)], [min(y_test_reg), max(y_test_reg)], color='red', linestyle='--')
plt.xlabel('Actual RiskScore')
plt.ylabel('Predicted RiskScore')
plt.title('Actual vs Predicted RiskScore (Random Forest Regression)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2. Gradient Boosting Regression

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Initialize the Gradient Boosting Regressor
gb_regressor = GradientBoostingRegressor(n_estimators=100, random_state=42)

# %%
# Fit the model
gb_regressor.fit(X_train_reg, y_train_reg)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
# Predict on the test data
y_pred_gb = gb_regressor.predict(X_test_reg)

# %%
# Calculate R-squared, MSE, RMSE, and MAE
r2_gb = r2_score(y_test_reg, y_pred_gb)
mse_gb = mean_squared_error(y_test_reg, y_pred_gb)
rmse_gb = np.sqrt(mse_gb)
mae_gb = mean_absolute_error(y_test_reg, y_pred_gb)

# Print the evaluation metrics
print(f"R-squared: {r2_gb:.4f}")
print(f"Mean Squared Error (MSE): {mse_gb:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_gb:.4f}")
print(f"Mean Absolute Error (MAE): {mae_gb:.4f}")
# Out:
# R-squared: 0.8822
# Mean Squared Error (MSE): 7.3145
# Root Mean Squared Error (RMSE): 2.7045
# Mean Absolute Error (MAE): 1.8528

# %%
# Plot Actual vs Predicted values for Gradient Boosting Regression
plt.figure(figsize=(10,6))
plt.scatter(y_test_reg, y_pred_gb, color='green', alpha=0.6)
plt.plot([min(y_test_reg), max(y_test_reg)], [min(y_test_reg), max(y_test_reg)], color='red', linestyle='--')
plt.xlabel('Actual RiskScore')
plt.ylabel('Predicted RiskScore')
plt.title('Actual vs Predicted RiskScore (Gradient Boosting Regression)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 3. XGBoost Regression

# %%
import xgboost as xgb

# Initialize the XGBoost Regressor
xgb_regressor = xgb.XGBRegressor(n_estimators=100, random_state=42)

# %%
# Fit the model
xgb_regressor.fit(X_train_reg, y_train_reg)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Predict on the test data
y_pred_xgb = xgb_regressor.predict(X_test_reg)

# %%
# Calculate R-squared, MSE, RMSE, and MAE
r2_xgb = r2_score(y_test_reg, y_pred_xgb)
mse_xgb = mean_squared_error(y_test_reg, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
mae_xgb = mean_absolute_error(y_test_reg, y_pred_xgb)

# Print the evaluation metrics
print(f"R-squared: {r2_xgb:.4f}")
print(f"Mean Squared Error (MSE): {mse_xgb:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_xgb:.4f}")
print(f"Mean Absolute Error (MAE): {mae_xgb:.4f}")
# Out:
# R-squared: 0.8967
# Mean Squared Error (MSE): 6.4159
# Root Mean Squared Error (RMSE): 2.5330
# Mean Absolute Error (MAE): 1.6723

# %%
# Plot Actual vs Predicted values for XGBoost Regression
plt.figure(figsize=(10,6))
plt.scatter(y_test_reg, y_pred_xgb, color='purple', alpha=0.6)
plt.plot([min(y_test_reg), max(y_test_reg)], [min(y_test_reg), max(y_test_reg)], color='red', linestyle='--')
plt.xlabel('Actual RiskScore')
plt.ylabel('Predicted RiskScore')
plt.title('Actual vs Predicted RiskScore (XGBoost Regression)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Model Comparison for Risk Score Forecasting

# %%
# MSE, RMSE, MAE, and R-squared values for each model
mse_scores = [mse_rf, mse_gb, mse_xgb]
rmse_scores = [rmse_rf, rmse_gb, rmse_xgb]
mae_scores = [mae_rf, mae_gb, mae_xgb]
r2_scores = [r2_rf, r2_gb, r2_xgb]
models = ['Random Forest', 'Gradient Boosting', 'XGBoost']

# MSE Plot
plt.figure(figsize=(8, 6))
plt.bar(models, mse_scores, color=['blue', 'green', 'purple'], alpha=0.7)
plt.title('Model Comparison: MSE for RiskScore Forecasting')
plt.xlabel('Models')
plt.ylabel('Mean Squared Error (MSE)')
for i, v in enumerate(mse_scores):
    plt.text(i, v + 0.5, f'{v:.4f}', ha='center', va='bottom', fontsize=12)
plt.tight_layout()
plt.grid(True)
plt.show()

# RMSE Plot
plt.figure(figsize=(8, 6))
plt.bar(models, rmse_scores, color=['blue', 'green', 'purple'], alpha=0.7)
plt.title('Model Comparison: RMSE for RiskScore Forecasting')
plt.xlabel('Models')
plt.ylabel('Root Mean Squared Error (RMSE)')
for i, v in enumerate(rmse_scores):
    plt.text(i, v + 0.2, f'{v:.4f}', ha='center', va='bottom', fontsize=12)
plt.tight_layout()
plt.grid(True)
plt.show()

# MAE Plot (Adjusting the label position to prevent overlap)
plt.figure(figsize=(8, 6))
plt.bar(models, mae_scores, color=['blue', 'green', 'purple'], alpha=0.7)
plt.title('Model Comparison: MAE for RiskScore Forecasting')
plt.xlabel('Models')
plt.ylabel('Mean Absolute Error (MAE)')
for i, v in enumerate(mae_scores):
    plt.text(i, v + 0.1, f'{v:.4f}', ha='center', va='bottom', fontsize=12)  # Adjusted label position
plt.tight_layout()
plt.grid(True)
plt.show()

# R-squared Plot (Adding count values to the graph)
plt.figure(figsize=(8, 6))
plt.bar(models, r2_scores, color=['blue', 'green', 'purple'], alpha=0.7)
plt.title('Model Comparison: R-squared for RiskScore Forecasting')
plt.xlabel('Models')
plt.ylabel('R-squared')
for i, v in enumerate(r2_scores):
    plt.text(i, v + 0.01, f'{v:.4f}', ha='center', va='bottom', fontsize=12)  # Added count labels
plt.tight_layout()
plt.grid(True)
plt.show()

# Conclusion based on the MSE, RMSE, MAE, and R-squared values
print(f"\nComparison of Models based on MSE, RMSE, MAE, and R-squared:")
print(f"Random Forest - MSE: {mse_rf:.4f}, RMSE: {rmse_rf:.4f}, MAE: {mae_rf:.4f}, R-squared: {r2_rf:.4f}")
print(f"Gradient Boosting - MSE: {mse_gb:.4f}, RMSE: {rmse_gb:.4f}, MAE: {mae_gb:.4f}, R-squared: {r2_gb:.4f}")
print(f"XGBoost - MSE: {mse_xgb:.4f}, RMSE: {rmse_xgb:.4f}, MAE: {mae_xgb:.4f}, R-squared: {r2_xgb:.4f}")

# Determine the best model based on MSE, RMSE, MAE, and R-squared (lower MSE, RMSE, MAE; higher R-squared is better)
best_model = min([(r2_rf, mse_rf, rmse_rf, mae_rf, "Random Forest"),
                  (r2_gb, mse_gb, rmse_gb, mae_gb, "Gradient Boosting"),
                  (r2_xgb, mse_xgb, rmse_xgb, mae_xgb, "XGBoost")], key=lambda x: (x[1], x[2], x[3], -x[0]))

print(f"\nConclusion based on evaluation metrics: The best model is {best_model[4]} with the following values:")
print(f"MSE: {best_model[1]:.4f}, RMSE: {best_model[2]:.4f}, MAE: {best_model[3]:.4f}, R-squared: {best_model[0]:.4f}")
# Out:
# Comparison of Models based on MSE, RMSE, MAE, and R-squared:
# Random Forest - MSE: 7.5431, RMSE: 2.7465, MAE: 1.7082, R-squared: 0.8785
# Gradient Boosting - MSE: 7.3145, RMSE: 2.7045, MAE: 1.8528, R-squared: 0.8822
# XGBoost - MSE: 6.4159, RMSE: 2.5330, MAE: 1.6723, R-squared: 0.8967
#
# Conclusion based on evaluation metrics: The best model is XGBoost with the following values:
# MSE: 6.4159, RMSE: 2.5330, MAE: 1.6723, R-squared: 0.8967

# %% [markdown]
# ## Deploying the best-fitted model

# %%
pickle.dump(xgb_regressor, open("xgb_regressor.pkl", 'wb'))

# %%
import tkinter as tk
from tkinter import messagebox


regression_model = pickle.load(open("xgb_regressor.pkl", 'rb'))


app = tk.Tk()
app.title("Risk Score Prediction")
app.geometry("400x600")  # Compact window size

# Function to predict using the loaded model
def predict_regression():
    try:
        
        bankruptcy_history = int(bankruptcy_history_entry.get())
        total_debt_to_income = float(total_debt_to_income_entry.get())
        debt_to_income = float(debt_to_income_entry.get())
        interest_rate = float(interest_rate_entry.get())
        previous_loan_defaults = int(previous_loan_defaults_entry.get())
        base_interest_rate = float(base_interest_rate_entry.get())
        loan_amount = float(loan_amount_entry.get())
        employment_status = employment_status_entry.get().strip()
        monthly_loan_payment = float(monthly_loan_payment_entry.get())
        credit_card_utilization = float(credit_card_utilization_entry.get())

        
        employment_mapping = {"Employed": 0, "Self-Employed": 1, "Unemployed": 2}
        employment_status_encoded = employment_mapping.get(employment_status, -1)
        if employment_status_encoded == -1:
            raise ValueError("Invalid Employment Status")

        
        input_features = np.array([[  
            bankruptcy_history, total_debt_to_income, debt_to_income,
            interest_rate, previous_loan_defaults, base_interest_rate,
            loan_amount, employment_status_encoded, monthly_loan_payment,
            credit_card_utilization
        ]])

        
        prediction = regression_model.predict(input_features)[0]
        
        
        messagebox.showinfo("Regression Result", f"Predicted Risk Score: {prediction:.2f}")
    except ValueError as e:
        messagebox.showerror("Invalid Input", str(e))


regression_label = tk.Label(app, text="Risk Score Prediction", font=("Arial", 12, "bold"))
regression_label.pack(pady=5)


regression_labels = [
    "Bankruptcy History", "Total Debt to Income (%)", "Debt to Income (%)",
    "Interest Rate (%)", "Previous Loan Defaults", "Base Interest Rate (%)",
    "Loan Amount ($)", "Employment (Employed/Self-Employed/Unemployed)",
    "Monthly Loan Payment ($)", "Credit Card Utilization (%)"
]


regression_entries = []
for label_text in regression_labels:
    label = tk.Label(app, text=label_text, font=("Arial", 10))
    label.pack(pady=2)  

    entry = tk.Entry(app, font=("Arial", 10))
    entry.pack(pady=2)
    regression_entries.append(entry)


(bankruptcy_history_entry, total_debt_to_income_entry, debt_to_income_entry,
 interest_rate_entry, previous_loan_defaults_entry, base_interest_rate_entry,
 loan_amount_entry, employment_status_entry, monthly_loan_payment_entry,
 credit_card_utilization_entry) = regression_entries


predict_regression_button = tk.Button(
    app, 
    text="Predict Risk Score", 
    command=predict_regression, 
    font=("Arial", 12), 
    bg="green", 
    fg="white"
)
predict_regression_button.pack(pady=10)


app.mainloop()
